# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("Standardized_Sentiment_Analysis_Dataset (1).csv")  # e.g., text,label

# %%
import pandas as pd
df=pd.read_csv("Standardized_Sentiment_Analysis_Dataset (1).csv")
df.head()
# Out:
#    S.No.                                            message sentiment
# 0      1  also appeared give him kiss the cheek reminisc...   Neutral
# 1      2  trust modi and india will regret one strike fr...  Negative
# 2      3  report that not published states that  aise ga...   Neutral
# 3      4  hater your modis war and hate mongering page s...  Negative
# 4      5  modi actually never promised lakhs into every ...   Neutral

# %%
data.dropna(inplace=True)
X = data['message']
y = data['sentiment']

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
X_vectorized = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_vectorized, y, test_size=0.2, random_state=42)

# %%
X
# Out:
# 0        also appeared give him kiss the cheek reminisc...
# 1        trust modi and india will regret one strike fr...
# 2        report that not published states that  aise ga...
# 3        hater your modis war and hate mongering page s...
# 4        modi actually never promised lakhs into every ...
#                                ...
# 99995    It met the basic expectations. Management box ...
# 99996    Nothing special. Authority despite central on ...
# 99997    Very disappointed. Mrs interview wait sort cha...
# 99998    Totally unacceptable. Way hair summer way open...
# 99999    Poor quality and service. Trouble possible hel...
# Name: message, Length: 99999, dtype: object

# %%
y
# Out:
# 0         Neutral
# 1        Negative
# 2         Neutral
# 3        Negative
# 4         Neutral
#            ...
# 99995     Neutral
# 99996     Neutral
# 99997    Negative
# 99998    Negative
# 99999    Negative
# Name: sentiment, Length: 99999, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)

# %%
def predict_sentiment(chat_input):
    cleaned = clean_text(chat_input)
    vector = vectorizer.transform([cleaned]).toarray()
    prediction = model.predict(vector)[0]
    return label_encoder.inverse_transform([prediction])[0]

# %%
label_map = {0: "Negative", 1: "Neutral", 2: "Positive"}

def predict_sentiment(chat_input):
    cleaned = clean_text(chat_input)
    vector = vectorizer.transform([cleaned]).toarray()
    prediction = model.predict(vector)[0]
    return label_map[prediction]

# %%
from xgboost import XGBClassifier
classifier = XGBClassifier()
classifier.fit(X = X_train,y =  y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
model.fit(X_train, y_train)
# Out:
# F:\New folder\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:27:38] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
y_pred = le.inverse_transform(y_pred)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[5330  666  731]
#  [  76 6377   26]
#  [ 396  769 5629]]
# 0.8668

# %%
print("Accuracy Score:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.8668
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative       0.92      0.79      0.85      6727
#      Neutral       0.82      0.98      0.89      6479
#     Positive       0.88      0.83      0.85      6794
#
#     accuracy                           0.87     20000
#    macro avg       0.87      0.87      0.87     20000
# weighted avg       0.87      0.87      0.87     20000

# %%
from sklearn.preprocessing import LabelEncoder

# Encode sentiment labels
label_encoder = LabelEncoder()
df['sentiment_encoded'] = label_encoder.fit_transform(df['sentiment'])

# %%
def predict_sentiment(text):
    text_vector = vectorizer.transform([text])
    prediction = model.predict(text_vector)[0]
    sentiment_label = label_encoder.inverse_transform([prediction])[0]
    return sentiment_label

# Step 9: User input loop
print("\nEnter your message below (type 'exit' to quit):")
while True:
    user_input = input("Message: ").strip()
    if user_input.lower() == 'exit':
        print("Exiting.")
        break
    elif user_input == "":
        print("Please enter a non-empty message.")
    else:
        sentiment = predict_sentiment(user_input)
        print(f"Predicted Sentiment: {sentiment}\n")
# Out:
# Enter your message below (type 'exit' to quit):
# Message:  happy
# Predicted Sentiment: Positive
# Message:  sad
# Predicted Sentiment: Negative
# Message:  good
# Predicted Sentiment: Positive
# Message:  exit
# Exiting.
